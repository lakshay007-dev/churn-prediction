# %%
import numpy as np
import pandas as pd
import statistics
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
df=pd.read_csv('HR_Data.csv')
df.head()
# Out:
#    SLNO  Candidate.Ref DOJ.Extended  Duration.to.accept.offer  Notice.period  \
# 0     1        2110407          Yes                        14             30
# 1     2        2112635           No                        18             30
# 2     3        2112838           No                         3             45
# 3     4        2115021           No                        26             30
# 4     5        2115125          Yes                         1            120
#
#   Offered.band  Pecent.hike.expected.in.CTC  Percent.hike.offered.in.CTC  \
# 0           E2                       -20.79                        13.16
# 1           E2                        50.00                       320.00
# 2           E2                        42.84                        42.84
# 3           E2                        42.84                        42.84
# 4           E2                        42.59                        42.59
#
# ...

# %%
df['Candidate.Ref'].nunique()
# Out:
# 8995

# %%
df['DOJ.Extended'] = df['DOJ.Extended'].apply(lambda x: 0 if x=='No' else 1)

# %%
df.head()
# Out:
#    SLNO  Candidate.Ref  DOJ.Extended  Duration.to.accept.offer  Notice.period  \
# 0     1        2110407             1                        14             30
# 1     2        2112635             0                        18             30
# 2     3        2112838             0                         3             45
# 3     4        2115021             0                        26             30
# 4     5        2115125             1                         1            120
#
#   Offered.band  Pecent.hike.expected.in.CTC  Percent.hike.offered.in.CTC  \
# 0           E2                       -20.79                        13.16
# 1           E2                        50.00                       320.00
# 2           E2                        42.84                        42.84
# 3           E2                        42.84                        42.84
# 4           E2                        42.59                        42.59
#
# ...

# %%
df['Duration.to.accept.offer']
# Out:
# 0       14
# 1       18
# 2        3
# 3       26
# 4        1
#         ..
# 8993     0
# 8994     2
# 8995     4
# 8996     5
# 8997     4
# Name: Duration.to.accept.offer, Length: 8998, dtype: int64

# %%
df['Duration.to.accept.offer'].max()
# Out:
# 224

# %%
df['DOJ.Extended'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.countplot(x=df['DOJ.Extended'] ,data = df)
plt.show()

# %%
df['Notice.period']
# Out:
# 0        30
# 1        30
# 2        45
# 3        30
# 4       120
#        ...
# 8993     30
# 8994      0
# 8995      0
# 8996      0
# 8997     30
# Name: Notice.period, Length: 8998, dtype: int64

# %%
df['Notice.period'].nunique()
# Out:
# 7

# %%
sns.countplot(x=df['Notice.period'],data=df)
plt.show()

# %%
df['Offered.band'].nunique()
# Out:
# 4

# %%
sns.countplot(x=df['Offered.band'],data=df)
plt.show()

# %%
df['Joining.Bonus'].nunique()
# Out:
# 2

# %%
sns.countplot(x=df['Joining.Bonus'],data=df)
plt.show()

# %%
df['Pecent.hike.expected.in.CTC'].nunique()
# Out:
# 2082

# %%
sns.boxplot(df['Pecent.hike.expected.in.CTC'])
plt.show()

# %%
df['Percent.hike.offered.in.CTC'].nunique()
# Out:
# 2601

# %%
sns.boxplot(df['Percent.hike.offered.in.CTC'])
plt.show()

# %%
df['Percent.difference.CTC'].nunique()
# Out:
# 1148

# %%
sns.boxplot(df['Percent.difference.CTC'])
plt.show()

# %%
df['Joining.Bonus'].nunique()
# Out:
# 2

# %%
sns.countplot(x=df['Joining.Bonus'],data=df)
plt.show()

# %%
df['Candidate.relocate.actual'].nunique()
# Out:
# 2

# %%
sns.countplot(x=df['Candidate.relocate.actual'],data=df)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
sns.countplot(x=df['Gender'])
plt.show()

# %%
df['Candidate.Source'].nunique()
# Out:
# 3

# %%
sns.countplot(x=df['Candidate.Source'])
plt.show()

# %%
df['Rex.in.Yrs'].nunique()
# Out:
# 22

# %%
sns.countplot(x=df['Rex.in.Yrs'])
plt.show()

# %%
df['LOB'].nunique()
# Out:
# 9

# %%
plt.figure(figsize=(12,7))
sns.countplot(x=df['LOB'])
plt.show()

# %%
df['Location'].nunique()
# Out:
# 11

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df['Location'])
plt.show()

# %%
df['Status'].nunique()
# Out:
# 2

# %%
sns.countplot(x=df['Status'])
plt.show()
